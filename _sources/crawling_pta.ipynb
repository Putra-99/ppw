# %% [markdown]
# # Crawling Website PTA

# %% [markdown]
# # Install Library

# %%
# !pip install builtwith
# !pip install requests
# !pip install beautifulsoup4
# Out:
# Collecting builtwith
#   Downloading builtwith-1.3.4.tar.gz (34 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from builtwith) (1.17.0)
# Building wheels for collected packages: builtwith
#   Building wheel for builtwith (setup.py) ... done
#   Created wheel for builtwith: filename=builtwith-1.3.4-py3-none-any.whl size=36077 sha256=241355d21ced5a01b05f7d6848bbb6809bf854140b2bfca4aaea38e7786d1e32
#   Stored in directory: /root/.cache/pip/wheels/7f/2d/b2/606e3df914d4aeeab99c4a4e3e9a61673d2293c2e346db00c8
# Successfully built builtwith
# Installing collected packages: builtwith
# Successfully installed builtwith-1.3.4
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests) (2025.8.3)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (4.13.5)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4) (4.15.0)

# %% [markdown]
# # analisis teknologi yang digunakan dalam website

# %%
import  builtwith

chek = builtwith.parse('https://pta.trunojoyo.ac.id')
print(chek)
# Out:
# {'web-servers': ['Nginx'], 'javascript-frameworks': ['jQuery', 'jQuery UI']}

# %% [markdown]
# # Web Crawling

# %%
from os import name
import requests
from bs4 import BeautifulSoup

def crawling_link (url):
  try :
    r = requests.get(url)
    r.raise_for_status()  # Raise an error for bad status codes
    soup = BeautifulSoup(r.text, 'html.parser')

    # mengambil semua judul
    headings = soup.find_all('h1', 'h2','h3')
    for heading in headings:
      print(f"{headings.name}: {heading.get_text()}")

    # mengambil semua link
    links = soup.find_all('a', href = True)
    for link in links:
      print(f"URL: {link['href']} | Teks: {link.get_text()}")

  except requests.exceptions.RequestException as e:
        print(f"Terjadi kesalahan saat mengakses {url}: {e}")

# menampilkan
crawling_link('https://pta.trunojoyo.ac.id')
# Out:
# URL: index.html | Teks:
# URL: # | Teks: 14677Journal
# URL: https://pta.trunojoyo.ac.id/ | Teks: Beranda
# URL: https://pta.trunojoyo.ac.id/c_search/ | Teks: Pencarian
# URL: https://pta.trunojoyo.ac.id/c_template/ | Teks: Download
# URL: https://library.trunojoyo.ac.id/detil.php?id=23 | Teks: Petunjuk Upload
# URL: https://pta.trunojoyo.ac.id/c_contact/ | Teks: Kontak
# URL: # | Teks: STRATEGI PENGEMBANGAN MAKANAN DAN MINUMAN KHAS PULAU GILIGENTING GUNA MENDUKUNG PARIWISATA BERKELANJUTAN
# URL: https://pta.trunojoyo.ac.id/welcome/detail/170361100003 | Teks: Selengkapnya
# URL: # | Teks: PERUMUSAN SANKSI PIDANA BAGI MASYARAKAT SEKITAR HUTAN YANG MELAKUKAN PENCURIAN KAYU MILIK NEGARA DALAM UNDANG-UNDANG NOMOR 18 TAHUN 2013
# URL: https://pta.trunojoyo.ac.id/welcome/detail/170111100053 | Teks: Selengkapnya
# URL: # | Teks: Peran Teor Motivasi Herzberg Sebagai Mediator Self Efficacy, Lingkungan Kerja Dalam Meningkatkan Prestasi Kerja Pegawai ( Kantor Jasa Penilai Publik Guntur Eki Andri dan Rekan Kota Surabaya )
# URL: https://pta.trunojoyo.ac.id/welcome/detail/160211100116 | Teks: Selengkapnya
# URL: https://pta.trunojoyo.ac.id/welcome/index/2 | Teks: 2
# URL: https://pta.trunojoyo.ac.id/welcome/index/3 | Teks: 3
# URL: https://pta.trunojoyo.ac.id/welcome/index/2 | Teks: >
# URL: https://pta.trunojoyo.ac.id/welcome/index/4893 | Teks: »
# URL: https://pta.trunojoyo.ac.id/c_search/byfac/1 | Teks: Hukum
# URL: https://pta.trunojoyo.ac.id/c_search/byprod/1 | Teks: Ilmu Hukum
# URL: https://pta.trunojoyo.ac.id/c_search/byprod/24 | Teks: Magister Ilmu Hukum
# URL: https://pta.trunojoyo.ac.id/c_search/byfac/2 | Teks: Pertanian
# URL: https://pta.trunojoyo.ac.id/c_search/byprod/2 | Teks: Teknologi Industri Pertanian
# URL: https://pta.trunojoyo.ac.id/c_search/byprod/3 | Teks: Agribisnis
# URL: https://pta.trunojoyo.ac.id/c_search/byprod/4 | Teks: Agroteknologi
# URL: https://pta.trunojoyo.ac.id/c_search/byprod/5 | Teks: Ilmu Kelautan
# URL: https://pta.trunojoyo.ac.id/c_search/byprod/35 | Teks: Manajemen Sumberdaya Perairan
# URL: https://pta.trunojoyo.ac.id/c_search/byprod/37 | Teks: Magister Pengelolaan Sumber Daya Alam
# URL: https://pta.trunojoyo.ac.id/c_search/byfac/3 | Teks: Ekonomi Dan Bisnis
# URL: https://pta.trunojoyo.ac.id/c_search/byprod/6 | Teks: Ekonomi Pembangunan
# URL: https://pta.trunojoyo.ac.id/c_search/byprod/7 | Teks: Manajemen
# URL: https://pta.trunojoyo.ac.id/c_search/byprod/8 | Teks: Akuntansi
# URL: https://pta.trunojoyo.ac.id/c_search/byprod/21 | Teks: D3 Akuntansi
# URL: https://pta.trunojoyo.ac.id/c_search/byprod/22 | Teks: Magister Manajemen
# URL: https://pta.trunojoyo.ac.id/c_search/byprod/25 | Teks: Magister Akuntansi
# URL: https://pta.trunojoyo.ac.id/c_search/byprod/26 | Teks: D3 Enterpreneurship
# URL: https://pta.trunojoyo.ac.id/c_search/byprod/36 | Teks: Magister Ilmu Ekonomi
# URL: https://pta.trunojoyo.ac.id/c_search/byprod/41 | Teks: Doktor Ilmu Manajemen
# URL: https://pta.trunojoyo.ac.id/c_search/byfac/4 | Teks: Teknik
# URL: https://pta.trunojoyo.ac.id/c_search/byprod/9 | Teks: Teknik Industri
# URL: https://pta.trunojoyo.ac.id/c_search/byprod/10 | Teks: Teknik Informatika
# URL: https://pta.trunojoyo.ac.id/c_search/byprod/11 | Teks: Manajemen Informatika
# URL: https://pta.trunojoyo.ac.id/c_search/byprod/19 | Teks: Teknik Multimedia Dan Jaringan
# URL: https://pta.trunojoyo.ac.id/c_search/byprod/20 | Teks: Mekatronika
# URL: https://pta.trunojoyo.ac.id/c_search/byprod/23 | Teks: Teknik Elektro
# URL: https://pta.trunojoyo.ac.id/c_search/byprod/31 | Teks: Sistem Informasi
# URL: https://pta.trunojoyo.ac.id/c_search/byprod/32 | Teks: Teknik Mesin
# URL: https://pta.trunojoyo.ac.id/c_search/byprod/33 | Teks: Teknik Mekatronika
# URL: https://pta.trunojoyo.ac.id/c_search/byfac/5 | Teks: Ilmu Sosial Dan Ilmu Budaya
# URL: https://pta.trunojoyo.ac.id/c_search/byprod/12 | Teks: Sosiologi
# URL: https://pta.trunojoyo.ac.id/c_search/byprod/13 | Teks: Ilmu Komunikasi
# URL: https://pta.trunojoyo.ac.id/c_search/byprod/14 | Teks: Psikologi
# URL: https://pta.trunojoyo.ac.id/c_search/byprod/15 | Teks: Sastra Inggris
# URL: https://pta.trunojoyo.ac.id/c_search/byfac/6 | Teks: Keislaman
# URL: https://pta.trunojoyo.ac.id/c_search/byprod/16 | Teks: Ekonomi Syariah
# URL: https://pta.trunojoyo.ac.id/c_search/byprod/17 | Teks: Hukum Bisnis Syariah
# URL: https://pta.trunojoyo.ac.id/c_search/byfac/7 | Teks: Ilmu Pendidikan
# URL: https://pta.trunojoyo.ac.id/c_search/byprod/18 | Teks: Pgsd
# URL: https://pta.trunojoyo.ac.id/c_search/byprod/27 | Teks: Pendidikan Bhs Dan Sastra Indonesia
# URL: https://pta.trunojoyo.ac.id/c_search/byprod/28 | Teks: Pendidikan Informatika
# URL: https://pta.trunojoyo.ac.id/c_search/byprod/29 | Teks: Pendidikan Ipa
# URL: https://pta.trunojoyo.ac.id/c_search/byprod/30 | Teks: Pgpaud
# URL: https://pta.trunojoyo.ac.id/c_search/byprod/38 | Teks: Pendidikan Profesi Guru
# URL: https://pta.trunojoyo.ac.id/c_search/byfac/99 | Teks: Mbkm
# URL: https://pta.trunojoyo.ac.id/c_search/byprod/99 | Teks: Mbkm
# URL: https://pta.trunojoyo.ac.id/c_search/byfac/100 | Teks: Pascasarjana
# URL: https://pta.trunojoyo.ac.id/c_search/byprod/39 | Teks: Magister Pendidikan Dasar
# URL: https://pta.trunojoyo.ac.id/c_search/byprod/40 | Teks: Doktor Pengelolaan Sumber Daya Alam
# URL: https://pta.trunojoyo.ac.id/c_search/byfac/1 | Teks: Hukum
# URL: https://pta.trunojoyo.ac.id/c_search/byfac/2 | Teks: Pertanian
# URL: https://pta.trunojoyo.ac.id/c_search/byfac/3 | Teks: Ekonomi Dan Bisnis
# URL: https://pta.trunojoyo.ac.id/c_search/byfac/4 | Teks: Teknik
# URL: https://pta.trunojoyo.ac.id/c_search/byfac/5 | Teks: Ilmu Sosial Dan Ilmu Budaya
# URL: https://pta.trunojoyo.ac.id/c_search/byfac/6 | Teks: Keislaman
# URL: https://pta.trunojoyo.ac.id/c_search/byfac/7 | Teks: Ilmu Pendidikan
# URL: https://pta.trunojoyo.ac.id/c_search/byfac/99 | Teks: Mbkm
# URL: https://pta.trunojoyo.ac.id/c_search/byfac/100 | Teks: Pascasarjana
# URL: http://trunojoyo.ac.id | Teks: www.trunojoyo.ac.id
# URL: http://e-journal.dikti.go.id | Teks: http://e-journal.dikti.go.id
# URL: # | Teks:
# URL: # | Teks:
# URL: # | Teks:
# URL: # | Teks:
# URL: # | Teks:
# URL: # | Teks:
# URL: # | Teks:

# %% [markdown]
# # Web Scraping

# %%
import pandas as pd
import requests, time, json, os, sys
from bs4 import BeautifulSoup

PROGRESS_FILE = "pta_progress.json"
DATA_FILE = "pta.csv"

def save_progress(prodi_id, page):
    progress = {}
    if os.path.exists(PROGRESS_FILE):
        with open(PROGRESS_FILE, "r") as f:
            progress = json.load(f)
    progress["last_prodi"] = prodi_id
    progress["last_page"] = page
    with open(PROGRESS_FILE, "w") as f:
        json.dump(progress, f)

def load_progress():
    if os.path.exists(PROGRESS_FILE):
        with open(PROGRESS_FILE, "r") as f:
            progress = json.load(f)
        return progress.get("last_prodi", 1), progress.get("last_page", 0)
    return 1, 0

def safe_get(session, url, retries=3, delay=2):
    for attempt in range(retries):
        try:
            r = session.get(url, timeout=15)
            r.raise_for_status()
            return r
        except Exception as e:
            print(f"\nGagal akses {url} (percobaan {attempt+1}/{retries}): {e}")
            time.sleep(delay)
    return None

def ptaa(prodi_ids=range(1, 41), pages_per_prodi=3):
    """Scrape PTA Trunojoyo, maksimal pages_per_prodi halaman tiap prodi."""
    # lanjutkan data lama kalau ada
    if os.path.exists(DATA_FILE):
        df = pd.read_csv(DATA_FILE)
        data = df.to_dict(orient="list")
    else:
        data = {
            "penulis": [], "judul": [], "pembimbing_pertama": [],
            "pembimbing_kedua": [], "abstrak": [], "abstraction": []
        }

    session = requests.Session()
    session.headers.update({"User-Agent": "Mozilla/5.0"})

    last_prodi, last_page = load_progress()

    # cek jumlah halaman tiap prodi
    total_pages_all = {}
    for j in prodi_ids:
        url_first = f"https://pta.trunojoyo.ac.id/c_search/byprod/{j}/1"
        r = safe_get(session, url_first)
        if r is None:
            total_pages_all[j] = 1
            continue
        soup = BeautifulSoup(r.content, "html.parser")
        last_link = soup.select_one('ol.pagination a:contains("»")')
        if last_link and last_link.has_attr('href'):
            total_pages = int(last_link['href'].rstrip('/').split('/')[-1])
        else:
            pages = [int(a.text) for a in soup.select('ol.pagination a') if a.text.isdigit()]
            total_pages = max(pages) if pages else 1
        total_pages_all[j] = total_pages

    for j in prodi_ids:
        if j < last_prodi:
            continue

        total_pages = total_pages_all[j]
        print(f"\nProdi {j} punya {total_pages} halaman")

        start_page = last_page + 1 if j == last_prodi else 1
        start_time = time.time()

        # batasi 3 halaman per prodi (atau sesuai parameter)
        max_pages = min(total_pages, pages_per_prodi)

        for i in range(start_page, max_pages + 1):
            try:
                url = f"https://pta.trunojoyo.ac.id/c_search/byprod/{j}/{i}"
                print(f"Scraping {url}")
                r = safe_get(session, url)
                if r is None:
                    continue
                soup = BeautifulSoup(r.content, "html.parser")
                jurnals = soup.select('li[data-cat="#luxury"]')

                for jurnal in jurnals:
                    r_jurnal = safe_get(session, jurnal.select_one('a.gray.button')['href'])
                    if r_jurnal is None:
                        continue
                    soup1 = BeautifulSoup(r_jurnal.content, "html.parser")

                    isi = soup1.select_one('div#content_journal')
                    judul = isi.select_one('a.title').text

                    penulis = isi.select_one('span:contains("Penulis")').text.split(' : ')[1]
                    pembimbing_pertama = isi.select_one('span:contains("Dosen Pembimbing I")').text.split(' : ')[1]
                    pembimbing_kedua = isi.select_one('span:contains("Dosen Pembimbing II")').text.split(' :')[1]

                    ps = isi.select('p[align="justify"]')
                    abstrak = ps[0].get_text(separator=' ', strip=True) if ps else ""
                    abstraction = ps[1].get_text(separator=' ', strip=True) if len(ps) > 1 else ""

                    data["penulis"].append(penulis)
                    data["judul"].append(judul)
                    data["pembimbing_pertama"].append(pembimbing_pertama)
                    data["pembimbing_kedua"].append(pembimbing_kedua)
                    data["abstrak"].append(abstrak)
                    data["abstraction"].append(abstraction)

                # simpan progres dan CSV setiap halaman
                save_progress(j, i)
                pd.DataFrame(data).to_csv(DATA_FILE, index=False, encoding="utf-8-sig")

                time.sleep(1)

            except KeyboardInterrupt:
                print("\nProses dihentikan user. Progres disimpan.")
                pd.DataFrame(data).to_csv(DATA_FILE, index=False, encoding="utf-8-sig")
                return pd.DataFrame(data)
            except Exception as e:
                print(f"\nGagal halaman {i} prodi {j}: {e}")
                continue

    print("\nSelesai scraping.")
    pd.DataFrame(data).to_csv(DATA_FILE, index=False, encoding="utf-8-sig")
    return pd.DataFrame(data)

# %% [markdown]
# # Hasil Scraping Website PTA

# %%
ptaa()
# Out:
# /usr/local/lib/python3.12/dist-packages/soupsieve/css_parser.py:876: FutureWarning: The pseudo class ':contains' is deprecated, ':-soup-contains' should be used moving forward.
#   warnings.warn(  # noqa: B028
# Prodi 1 punya 284 halaman
# Scraping https://pta.trunojoyo.ac.id/c_search/byprod/1/1
# Scraping https://pta.trunojoyo.ac.id/c_search/byprod/1/2
# Scraping https://pta.trunojoyo.ac.id/c_search/byprod/1/3
#
# Prodi 2 punya 114 halaman
# Scraping https://pta.trunojoyo.ac.id/c_search/byprod/2/1
# Scraping https://pta.trunojoyo.ac.id/c_search/byprod/2/2
# Scraping https://pta.trunojoyo.ac.id/c_search/byprod/2/3
#
# Prodi 3 punya 110 halaman
# Scraping https://pta.trunojoyo.ac.id/c_search/byprod/3/1
# Scraping https://pta.trunojoyo.ac.id/c_search/byprod/3/2
# Scraping https://pta.trunojoyo.ac.id/c_search/byprod/3/3
#
# Prodi 4 punya 116 halaman
# Scraping https://pta.trunojoyo.ac.id/c_search/byprod/4/1
# Scraping https://pta.trunojoyo.ac.id/c_search/byprod/4/2
# Scraping https://pta.trunojoyo.ac.id/c_search/byprod/4/3
#
# Prodi 5 punya 96 halaman
# Scraping https://pta.trunojoyo.ac.id/c_search/byprod/5/1
# Scraping https://pta.trunojoyo.ac.id/c_search/byprod/5/2
# Scraping https://pta.trunojoyo.ac.id/c_search/byprod/5/3
#
# Prodi 6 punya 118 halaman
# Scraping https://pta.trunojoyo.ac.id/c_search/byprod/6/1
# Scraping https://pta.trunojoyo.ac.id/c_search/byprod/6/2
# Scraping https://pta.trunojoyo.ac.id/c_search/byprod/6/3
#
# Prodi 7 punya 207 halaman
# Scraping https://pta.trunojoyo.ac.id/c_search/byprod/7/1
# Scraping https://pta.trunojoyo.ac.id/c_search/byprod/7/2
# Scraping https://pta.trunojoyo.ac.id/c_search/byprod/7/3
#
# Prodi 8 punya 177 halaman
# Scraping https://pta.trunojoyo.ac.id/c_search/byprod/8/1
# Scraping https://pta.trunojoyo.ac.id/c_search/byprod/8/2
# Scraping https://pta.trunojoyo.ac.id/c_search/byprod/8/3
#
# Prodi 9 punya 143 halaman
# Scraping https://pta.trunojoyo.ac.id/c_search/byprod/9/1
# Scraping https://pta.trunojoyo.ac.id/c_search/byprod/9/2
# Scraping https://pta.trunojoyo.ac.id/c_search/byprod/9/3
#
# Prodi 10 punya 172 halaman
# Scraping https://pta.trunojoyo.ac.id/c_search/byprod/10/1
# Scraping https://pta.trunojoyo.ac.id/c_search/byprod/10/2
# Scraping https://pta.trunojoyo.ac.id/c_search/byprod/10/3
#
# Prodi 11 punya 56 halaman
# Scraping https://pta.trunojoyo.ac.id/c_search/byprod/11/1
# Scraping https://pta.trunojoyo.ac.id/c_search/byprod/11/2
# Scraping https://pta.trunojoyo.ac.id/c_search/byprod/11/3
#
# Prodi 12 punya 136 halaman
# Scraping https://pta.trunojoyo.ac.id/c_search/byprod/12/1
# Scraping https://pta.trunojoyo.ac.id/c_search/byprod/12/2
# Scraping https://pta.trunojoyo.ac.id/c_search/byprod/12/3
#
# Prodi 13 punya 135 halaman
# Scraping https://pta.trunojoyo.ac.id/c_search/byprod/13/1
# Scraping https://pta.trunojoyo.ac.id/c_search/byprod/13/2
# Scraping https://pta.trunojoyo.ac.id/c_search/byprod/13/3
#
# Prodi 14 punya 104 halaman
# Scraping https://pta.trunojoyo.ac.id/c_search/byprod/14/1
# Scraping https://pta.trunojoyo.ac.id/c_search/byprod/14/2
# Scraping https://pta.trunojoyo.ac.id/c_search/byprod/14/3
#
# Prodi 15 punya 133 halaman
# Scraping https://pta.trunojoyo.ac.id/c_search/byprod/15/1
# Scraping https://pta.trunojoyo.ac.id/c_search/byprod/15/2
# Scraping https://pta.trunojoyo.ac.id/c_search/byprod/15/3
#
# Prodi 16 punya 113 halaman
# Scraping https://pta.trunojoyo.ac.id/c_search/byprod/16/1
# Scraping https://pta.trunojoyo.ac.id/c_search/byprod/16/2
# Scraping https://pta.trunojoyo.ac.id/c_search/byprod/16/3
#
# Prodi 17 punya 83 halaman
# Scraping https://pta.trunojoyo.ac.id/c_search/byprod/17/1
# Scraping https://pta.trunojoyo.ac.id/c_search/byprod/17/2
# Scraping https://pta.trunojoyo.ac.id/c_search/byprod/17/3
#
# Prodi 18 punya 183 halaman
# Scraping https://pta.trunojoyo.ac.id/c_search/byprod/18/1
# Scraping https://pta.trunojoyo.ac.id/c_search/byprod/18/2
# Scraping https://pta.trunojoyo.ac.id/c_search/byprod/18/3
#
# Prodi 19 punya 27 halaman
# Scraping https://pta.trunojoyo.ac.id/c_search/byprod/19/1
# Scraping https://pta.trunojoyo.ac.id/c_search/byprod/19/2
# Scraping https://pta.trunojoyo.ac.id/c_search/byprod/19/3
#
# Prodi 20 punya 28 halaman
# Scraping https://pta.trunojoyo.ac.id/c_search/byprod/20/1
# Scraping https://pta.trunojoyo.ac.id/c_search/byprod/20/2
# Scraping https://pta.trunojoyo.ac.id/c_search/byprod/20/3
#
# Prodi 21 punya 31 halaman
# Scraping https://pta.trunojoyo.ac.id/c_search/byprod/21/1
# Scraping https://pta.trunojoyo.ac.id/c_search/byprod/21/2
# Scraping https://pta.trunojoyo.ac.id/c_search/byprod/21/3
#
# Prodi 22 punya 14 halaman
# Scraping https://pta.trunojoyo.ac.id/c_search/byprod/22/1
# Scraping https://pta.trunojoyo.ac.id/c_search/byprod/22/2
# Scraping https://pta.trunojoyo.ac.id/c_search/byprod/22/3
#
# Prodi 23 punya 34 halaman
# Scraping https://pta.trunojoyo.ac.id/c_search/byprod/23/1
# Scraping https://pta.trunojoyo.ac.id/c_search/byprod/23/2
# Scraping https://pta.trunojoyo.ac.id/c_search/byprod/23/3
#
# Prodi 24 punya 14 halaman
# Scraping https://pta.trunojoyo.ac.id/c_search/byprod/24/1
# Scraping https://pta.trunojoyo.ac.id/c_search/byprod/24/2
# Scraping https://pta.trunojoyo.ac.id/c_search/byprod/24/3
#
# Prodi 25 punya 19 halaman
# Scraping https://pta.trunojoyo.ac.id/c_search/byprod/25/1
# Scraping https://pta.trunojoyo.ac.id/c_search/byprod/25/2
# Scraping https://pta.trunojoyo.ac.id/c_search/byprod/25/3
#
# Prodi 26 punya 15 halaman
# Scraping https://pta.trunojoyo.ac.id/c_search/byprod/26/1
# Scraping https://pta.trunojoyo.ac.id/c_search/byprod/26/2
# Scraping https://pta.trunojoyo.ac.id/c_search/byprod/26/3
#
# Prodi 27 punya 73 halaman
# Scraping https://pta.trunojoyo.ac.id/c_search/byprod/27/1
# Scraping https://pta.trunojoyo.ac.id/c_search/byprod/27/2
# Scraping https://pta.trunojoyo.ac.id/c_search/byprod/27/3
#
# Prodi 28 punya 70 halaman
# Scraping https://pta.trunojoyo.ac.id/c_search/byprod/28/1
# Scraping https://pta.trunojoyo.ac.id/c_search/byprod/28/2
# Scraping https://pta.trunojoyo.ac.id/c_search/byprod/28/3
#
# Prodi 29 punya 84 halaman
# Scraping https://pta.trunojoyo.ac.id/c_search/byprod/29/1
# Scraping https://pta.trunojoyo.ac.id/c_search/byprod/29/2
# Scraping https://pta.trunojoyo.ac.id/c_search/byprod/29/3
#
# Prodi 30 punya 53 halaman
# Scraping https://pta.trunojoyo.ac.id/c_search/byprod/30/1
# Scraping https://pta.trunojoyo.ac.id/c_search/byprod/30/2
# Scraping https://pta.trunojoyo.ac.id/c_search/byprod/30/3
#
# Prodi 31 punya 1 halaman
# Scraping https://pta.trunojoyo.ac.id/c_search/byprod/31/1
#
# Prodi 32 punya 1 halaman
# Scraping https://pta.trunojoyo.ac.id/c_search/byprod/32/1
#
# Prodi 33 punya 3 halaman
# Scraping https://pta.trunojoyo.ac.id/c_search/byprod/33/1
# Scraping https://pta.trunojoyo.ac.id/c_search/byprod/33/2
# Scraping https://pta.trunojoyo.ac.id/c_search/byprod/33/3
#
# Prodi 34 punya 1 halaman
# Scraping https://pta.trunojoyo.ac.id/c_search/byprod/34/1
#
# Prodi 35 punya 2 halaman
# Scraping https://pta.trunojoyo.ac.id/c_search/byprod/35/1
# Scraping https://pta.trunojoyo.ac.id/c_search/byprod/35/2
#
# Prodi 36 punya 2 halaman
# Scraping https://pta.trunojoyo.ac.id/c_search/byprod/36/1
# Scraping https://pta.trunojoyo.ac.id/c_search/byprod/36/2
#
# Prodi 37 punya 1 halaman
# Scraping https://pta.trunojoyo.ac.id/c_search/byprod/37/1
#
# Prodi 38 punya 1 halaman
# Scraping https://pta.trunojoyo.ac.id/c_search/byprod/38/1
#
# Prodi 39 punya 1 halaman
# Scraping https://pta.trunojoyo.ac.id/c_search/byprod/39/1
#
# Prodi 40 punya 1 halaman
# Scraping https://pta.trunojoyo.ac.id/c_search/byprod/40/1
#
# Selesai scraping.
#                               penulis  \
# 0                 Dyah Ayu Citra Seza
# 1                    Maulina Nurlaily
# 2                 Moh. Samsul Hidayat
# 3    TOMMY ADITYA PARLINDUNGAN MARBUN
# 4                  RICA YENA IMADHORA
# ..                                ...
# 476   Lisa Sri rahmatullah, S. Sos. I
# 477                Indah Ainun Nikmah
# 478                ahmad syaiful umam
# 479                      Siti Holifah
# 480                   Mohammad Maskur
#
#                                                  judul  \
# 0    Implementasi Fungsi Legislasi Dewan Perwakilan...
# 1    Pertanggungjawaban Pidana Direksi BUMN (Perser...
# 2    Analisis Terhadap Kekosongan Hukum dalam Penga...
# 3    PERLINDUNGAN HUKUM BAGI KONSUMEN ATAS PRODUK E...
# 4    TELAAH  KRITIS TENTANG ALASAN HUKUM YANG DIGUN...
# ..                                                 ...
# 476  Dampak Sosial Ekonomi Pariwisata Religi Makam ...
# 477  Peranan Zakat Produktif Dalam Meningkatkan Eko...
# 478  KARAKTERISASI DAN KOLEKSI PLASMA NUTFAH UNTUK ...
# 479  PENGOLAHAN LIMBAH AIR REBUSAN IKAN TERI MENJAD...
# 480  STRATEGI PENGEMBANGAN MAKANAN DAN MINUMAN KHAS...
#
#                      pembimbing_pertama  \
# 0       Yudi Widagdo Harimurti, SH., MH
# 1               Tolib Effendi, SH., MH.
# 2               Tolib Effendi, SH., MH.
# 3             DR. DJULAEKA, S.H., M.HUM
# 4            Dr. DENI SBY, S. H., M. S.
# ..                                  ...
# 476  Dr. Diah Wahyuningsih, S.E., M.Si.
# 477       Dr. Kurniyati Indahsari, M.Si
# 478           Dr. Ir. Gita Pawana, M.Si
# 479        Dr.Apri Arisandi,S.Pi.,M.Si.
# 480         Dr. Akhmad Farid, S.Pi., MT
#
#                           pembimbing_kedua  \
# 0                           Safi', SH., MH
# 1             Dr. Eni Suastuti, SH., Mhum.
# 2                  Agus Ramdlany, SH., MH.
# 3         DR.USWATUN HASANAH, S.H., M. HUM
# 4            SAIFUL ABDULLAH, S. H., M. H.
# ..                                     ...
# 476  Dr. Eni Sri Rahayuningsih, S.E., M.E.
# 477            Dr. Abdur Rahman, S.Ag. MEI
# 478         Dr. Ir. Hj. SIti Fatimah, M.Si
# 479                      Dr.Ir.H.Asfan,MP.
# 480         Dr. Apri Arisandi, S.Pi., M.Si
#
#                                                abstrak  \
# 0    ABSTRAK\r\n\r\n       Implementasi Fungsi Legi...
# 1    Badan Usaha Milik Negara (BUMN) adalah Badan u...
# 2    Kasus narkoba tidak henti-hentinya terdengar d...
# 3    Produk elektronik adalah suatu benda bergerak ...
# 4
# ..                                                 ...
# 476  Penelitian ini bertujuan untuk mengetahui baga...
# 477  Peranan Zakat Produktif dalam Meningkatkan Eko...
# 478  Madura merupakan salah satu wilayah pemasok ko...
# 479  Ikan Teri perlu penanganan serius pasca panen ...
# 480  Makanan dan minuman khas merupakan ciri dari k...
#
#                                            abstraction
# 0    ABSTRACT\r\n       Implementation of Legislati...
# 1    State Owned Enterprises (SOEs) are business en...
# 2    Drug cases endlessly heard on television, radi...
# 3    Electronic products is an object moves through...
# 4
# ..                                                 ...
# 476  The purpose of this study is to analyze the so...
# 477  The Role of Productive Zakat in Improving Must...
# 478  Madura is one of the regions supplying horticu...
# 479  Anchovy needs serious handling after harvest b...
# 480  Typical food and drinks are characteristic of ...
#
# [481 rows x 6 columns]
